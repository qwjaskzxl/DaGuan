# %%
import time
import cython
import numpy as np
from gensim.models import word2vec #必须按照[[],[]]才能保留原词！
from gensim.models.word2vec import LineSentence
from sklearn import preprocessing
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.externals import joblib
from sklearn import metrics

w2v_size = 300
def train_w2v(f_in1,f_in2):
    X = []
    loading_start = time.time()
    with open(f_in1,encoding='utf-8') as f1,open(f_in2,encoding='utf-8') as f2:
        lines = f1.readlines()[1:] + f2.readlines()[1:]
        X = [[] for i in range(len(lines))]
        i = 0
        for line in lines:
            line = line.split(',')
            X[i] = line[2].split(' ')#由于这一整个是str，但是w2v要一个个词
            i += 1
    print("Time consumption on loading:",time.time() - loading_start)

    train_start = time.time()
    model = word2vec.Word2Vec(X, size=w2v_size, min_count=3, workers=20)
    print(model)
    model.build_vocab(X)  # prepare the model vocabulary
    model.train(X, total_examples=len(X), epochs=model.iter)

    model.save('w2v_300_mincount3.model')
    # model.wv.save_word2vec_format("444.model.bin", binary=True)
    #增量学习 incremental/online learning
    # model = word2vec.Word2Vec.load('w2v.model')
    #model = word2vec.Word2Vec.load_word2vec_format("444.model.bin", binary=True)
    #model.build_vocab(X, update=True) #其实文档里都有的，虽然没有明确标出
    #model.train(X, total_examples=len(X), epochs=model.iter)

    # print(model.wv.vocab)
    print(model)
    print("Time consumption on training:", time.time() - train_start)

train_w2v('data/train_set.csv','data/test_set.csv')

"""
Time consumption on loading: 15.94904088973999
Word2Vec(vocab=241076, size=256, alpha=0.025)
Time consumption on training: 633.370879650116

Time consumption on loading: 14.4874107837677
Word2Vec(vocab=241076, size=300, alpha=0.025)
Time consumption on training: 624.7478380203247

Time consumption on loading: 13.424315929412842
Word2Vec(vocab=498683, size=200, alpha=0.025)
Time consumption on training: 743.550479888916

Time consumption on loading: 14.054274559020996
Word2Vec(vocab=498683, size=150, alpha=0.025)
Time consumption on training: 758.9731917381287
"""
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-52453a423ec9> in <module>()
#       2 import cython
#       3 import numpy as np
# ----> 4 from gensim.models import word2vec #必须按照[[],[]]才能保留原词！
#       5 from gensim.models.word2vec import LineSentence
#       6 from sklearn import preprocessing
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/__init__.py in <module>()
#       3 """
#       4
# ----> 5 from gensim import parsing, corpora, matutils, interfaces, models, similarities, summarization, utils  # noqa:F401
#       6 import logging
#       7
#
# ~/anaconda3/lib/python3.7/site-packages/gensim/corpora/__init__.py in <module>()
#       4
#       5 # bring corpus classes directly into package namespace, to save some typing
# ----> 6 from .indexedcorpus import IndexedCorpus  # noqa:F401 must appear before the other classes
#       7
# ...
